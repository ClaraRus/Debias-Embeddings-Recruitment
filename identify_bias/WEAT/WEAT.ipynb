# %%
# %load_ext autoreload
# %autoreload 2

# %%
from gensim.models import Word2Vec, Phrases, KeyedVectors
import json
import gensim.downloader as api
import numpy as np
import os

# %%
import pandas as pd

# %%
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from weat_test_cases import weat_test_cases
from weat_test_cases_recruitment_eng import weat_test_cases_recruitment_eng
from weat_test_cases_recruitment_dutch import weat_test_cases_recruitment_dutch
from weat_test_cases_recruitment_short_eng import weat_test_cases_recruitment_short_eng
from weat import check_consistency_weat, compute_weat_score, compute_combinations_weat_score, count_words_vocab, most_similar

# %% [markdown]
# # WORD2VEC

# %%
import gensim.downloader as api
word_vectors_gensim_w2vc = api.load("word2vec-google-news-300")
# Out:
# [===========================================-------] 86.9% 1445.4/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [============================================------] 88.9% 1478.2/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [==============================================----] 93.1% 1548.0/1662.8MB downloaded
# IOPub message rate exceeded.
# ...

# %% [markdown]
# ### WEAT

# %%
result_df = compute_weat_score(weat_test_cases, word_vectors_gensim_w2vc, bool_p=True)
result_df
# Out:
#                   Data Name                      Targets  \
# 0     Math_Arts_Male_Female     Math words vs Arts Words
# 1  Science_Arts_Male_Female  Science words vs Arts words
#
#                              Attributes Method     Score # of target words  \
# 0  Male attributes vs Female attributes   weat  0.932301                 8
# 1  Male attributes vs Female attributes   weat  1.195163                 8
#
#   # of attribute words  p-value
# 0                    8      0.0
# 1                    8      0.0

# %% [markdown]
# ### WEAT Recruitment

# %%
result_df = compute_weat_score(weat_test_cases_recruitment_eng, word_vectors_gensim_w2vc, bool_p=True)
result_df
# Out:
#                                            Data Name  \
# 0                     Industrial Work vs Office Work
# 1  Male dominated industry vs Female dominated in...
# 2                                    Career vs House
# 3               Science vs Female dominated industry
# 4                                 Expert vs Beginner
# 5                       Leader skills vs Team skills
#
#                                              Targets  \
# 0                     Industrial Work vs Office Work
# 1  Male dominated industry vs Female dominated in...
# 2                                    Career vs House
# 3               Science vs Female dominated industry
# 4                                 Expert vs Beginner
# 5                       Leader skills vs Team skills
#
#                              Attributes Method     Score # of target words  \
# 0  Male attributes vs Female attributes   weat  1.334124                 5
# ...

# %% [markdown]
# ### Check consistency of WEAT over different pairs of M/F attributes

# %%
attribute_list = [('masculine', 'feminine'), ('actress', 'actor'), ('womanly', 'manly'), ('girlish', 'boyish'), ('woman', 'man'), ('woman', 'masculine'), ('girly', 'masculine')]
X = 'constructor'
Y = 'nurse'
check_consistency_weat(X,Y, attribute_list, word_vectors_gensim_w2vc)
# Out:
#              X      Y          A          B  WEAT  p-value  count X  count Y  \
# 0  constructor  nurse  masculine   feminine   2.0      0.0  2904877  2993603
# 1  constructor  nurse    actress      actor  -2.0      0.0  2904877  2993603
# 2  constructor  nurse    womanly      manly  -2.0      0.0  2904877  2993603
# 3  constructor  nurse    girlish     boyish  -2.0      0.0  2904877  2993603
# 4  constructor  nurse      woman        man  -2.0      0.0  2904877  2993603
# 5  constructor  nurse      woman  masculine  -2.0      0.0  2904877  2993603
# 6  constructor  nurse      girly  masculine  -2.0      0.0  2904877  2993603
#
#    count A  count B
# 0  2964543  2976126
# 1  2996066  2997332
# 2  2863054  2952781
# 3  2889125  2949383
# 4  2999359  2999749
# 5  2999359  2964543
# 6  2941259  2964543

# %% [markdown]
# # GLOVE

# %%
word_vectors_gensim = api.load("glove-wiki-gigaword-100")
# Out:
# [==============================--------------------] 60.8% 77.8/128.1MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [==========================================--------] 84.4% 108.1/128.1MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %% [markdown]
# ### WEAT

# %%
result_df = compute_weat_score(weat_test_cases, word_vectors_gensim, bool_p=True)
result_df
# Out:
#                   Data Name                      Targets  \
# 0     Math_Arts_Male_Female     Math words vs Arts Words
# 1  Science_Arts_Male_Female  Science words vs Arts words
#
#                              Attributes Method     Score # of target words  \
# 0  Male attributes vs Female attributes   weat  1.339048                 8
# 1  Male attributes vs Female attributes   weat  1.169992                 8
#
#   # of attribute words  p-value
# 0                    8      0.0
# 1                    8      0.0

# %% [markdown]
# ### WEAT Recruitment

# %%
result_df = compute_weat_score(weat_test_cases_recruitment_eng, word_vectors_gensim, bool_p=True)
result_df
# Out:
#                                            Data Name  \
# 0                     Industrial Work vs Office Work
# 1  Male dominated industry vs Female dominated in...
# 2                                    Career vs House
# 3               Science vs Female dominated industry
# 4                                 Expert vs Beginner
# 5                       Leader skills vs Team skills
#
#                                              Targets  \
# 0                     Industrial Work vs Office Work
# 1  Male dominated industry vs Female dominated in...
# 2                                    Career vs House
# 3               Science vs Female dominated industry
# 4                                 Expert vs Beginner
# 5                       Leader skills vs Team skills
#
#                              Attributes Method     Score # of target words  \
# 0  Male attributes vs Female attributes   weat -0.078479                 5
# ...

# %% [markdown]
# ### Check consistency of WEAT over different pairs of M/F attributes

# %%
attribute_list = [('masculine', 'feminine'), ('actress', 'actor'), ('womanly', 'manly'), ('girlish', 'boyish'), ('woman', 'man'), ('woman', 'masculine'), ('girly', 'masculine')]
X = 'constructor'
Y = 'nurse'
check_consistency_weat(X,Y, attribute_list, word_vectors_gensim)
# Out:
#              X      Y          A          B  WEAT  p-value count X count Y  \
# 0  constructor  nurse  masculine   feminine   2.0      0.0  356068  393206
# 1  constructor  nurse    actress      actor  -2.0      0.0  356068  393206
# 2  constructor  nurse    womanly      manly  -2.0      0.0  356068  393206
# 3  constructor  nurse    girlish     boyish  -2.0      0.0  356068  393206
# 4  constructor  nurse      woman        man  -2.0      0.0  356068  393206
# 5  constructor  nurse      woman  masculine  -2.0      0.0  356068  393206
# 6  constructor  nurse      girly  masculine  -2.0      0.0  356068  393206
#
#   count A count B
# 0  381146  385094
# 1  397110  397982
# 2  300463  376234
# 3  336010  365335
# 4  399213  399700
# 5  399213  381146
# 6  327785  381146
